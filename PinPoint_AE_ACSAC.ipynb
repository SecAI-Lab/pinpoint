# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-c6493895-2ce2-7756-449d-016e6dfcdc40)

# %%
# !git clone https://github.com/SecAI-Lab/pinpoint /content/pinpoint
# Out:
# Cloning into '/content/pinpoint'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 112 (delta 29), reused 102 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 38.37 MiB | 34.46 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# !bash /content/pinpoint/install.sh
# Out:
# == 1/4  Python dependencies
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 46.0 MB/s eta 0:00:00
#     torch/torchvision already present -- left untouched
#     torch 2.11.0+cu128  cuda=True  device=Tesla T4
#     tensorflow already present -- left untouched
# 2026-09-17 01:51:07.604045: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#     tensorflow 2.20.0
# == 2/4  BCSD backbones
#     cloned 14 BinShot sources into artifact/binshot
#     cloned SAFE sources into artifact/safe_backbone
#     downloading the SAFE model (210 MiB)
#     model: checksum ok
#     downloading the SAFE vocabulary (inside a 420 MiB archive)
#     vocabulary: checksum ok
#     SAFE weights in artifact/models/safe
# == 3/4  Evaluation data
# [*] using the bundle shipped with the repository
# [*] verifying checksum
# /content/pinpoint/dist/pinpoint-acsac26-data.tar.gz: OK
# [*] unpacking into /content/pinpoint/artifact
# [+] done: 32 target binaries
#
# == 4/4  precomputing BinShot reference embeddings
#     [+] Saving unified embeddings to /content/pinpoint/artifact/data/reference_embeddings/reference_embeddings_regular.pt ...
#     [+] Done! File size: 2.4 MB
#     [+] Saving unified embeddings to /content/pinpoint/artifact/data/reference_embeddings/reference_embeddings_fno_inline.pt ...
#     [+] Done! File size: 1.5 MB
#
# == verifying layout
#     ok      artifact/binshot/binshot.py
#     ok      artifact/models/binshot_sim.model
#     ok      artifact/models/pretrain.all.corpus.voca
#     ok      artifact/data/reference_db/default.json
#     ok      artifact/data/reference_db/fno_inline.json
#     ok      artifact/data/ground_truth/gt_ranges.json
#     ok      artifact/data/ground_truth/ground_truth_v3.txt
#     ok      artifact/data/ground_truth/subset.json
#     ok      artifact/safe_backbone/asm_embedding/InstructionsConverter.py
#     ok      artifact/models/safe/safe_trained_X86.pb
#     ok      artifact/models/safe/word2id.json
#     ok      artifact/data/safe/reference_db/default.json
#     ok      artifact/data/safe/reference_db/fno_inline.json
#     ok      artifact/data/targets (32 binaries)
#     ok      artifact/data/safe/targets (32 binaries)
#
# [+] setup complete.
#     quick check (minutes) : bash artifact/scripts/smoke.sh
#     claim 1 (~4 hours)    : claims/claim1/run.sh
#     claim 2 (seconds)     : claims/claim2/run.sh

# %%
# !bash /content/pinpoint/claims/claim1/run.sh
# Out:
# == BinShot: full cascade over the subset
# [+] Using device: cuda:0
# [+] MAX_TOKENS: 253
# [+] Vuln DBs to process: ['regular', 'fno_inline']
# [+] Running all stages: Stage 1, 2, 3 (early-exit at >= 0.99)
# [+] Filter (pre-filter, minimum code-mass): ENABLED  α = 0.54
# [+] Loading vocabulary from /content/pinpoint/artifact/models/pretrain.all.corpus.voca
# [+] Loaded 17992 vocas
# [+] Loading similarity model from /content/pinpoint/artifact/models/binshot_sim.model
# [+] Excluded 0 files with opts ['O0'] (32 remain)
# [+] Target files to process: 32
# [+] Mode: SAME project/binary only
#
# ========== Vuln DB: regular ==========
# [+] Path: /content/pinpoint/artifact/data/reference_db/default.json
# [+] Output dir: /content/pinpoint/artifact/results/cascade/regular
# [+] Loading vulnerable functions from /content/pinpoint/artifact/data/reference_db/default.json
# [+] Loaded 139 vulnerable functions
# [+] Loaded 139 vuln queries from DB
# [+] Loading pre-computed embeddings for 'regular' from /content/pinpoint/artifact/data/reference_embeddings/reference_embeddings_regular.pt
# [+] Loaded 139 embeddings (mode: unified)
#
# ========== Vuln DB: fno_inline ==========
# [+] Path: /content/pinpoint/artifact/data/reference_db/fno_inline.json
# [+] Output dir: /content/pinpoint/artifact/results/cascade/fno_inline
# [+] Loading vulnerable functions from /content/pinpoint/artifact/data/reference_db/fno_inline.json
# [+] Loaded 81 vulnerable functions
# [+] Loaded 81 vuln queries from DB
# [+] Loading pre-computed embeddings for 'fno_inline' from /content/pinpoint/artifact/data/reference_embeddings/reference_embeddings_fno_inline.pt
# [+] Loaded 81 embeddings (mode: unified)
# Run overall 0/64 [00:00<?]
# Run (waiting) 0/1  [00:00]
# Run (waiting) 0/3  [00:00]
# Run [regular] coreutils-pr-23-gcc-O3.json:  0/3  [00:00]
# Run [regular] coreutils-pr-23-gcc-O3.json:  0/3  [00:00]
# Run [regular] coreutils-pr-23-gcc-O3.json:  0/3 , stage2 [00:00]
# Run [regular] coreutils-pr-23-gcc-O3.json:  0/3 , stage3 [00:05]
# Run [regular] coreutils-pr-23-gcc-O3.json:  1/3 , stage3 [00:08]
# Run [regular] coreutils-pr-23-gcc-O3.json:  1/3 , stage2 [00:08]
# Run [regular] coreutils-pr-23-gcc-O3.json:  1/3 , stage3 [00:13]
# Run [regular] coreutils-pr-23-gcc-O3.json:  2/3 , stage3 [00:16]
# Run [regular] coreutils-pr-23-gcc-O3.json:  2/3 , stage2 [00:16]
# Run [regular] coreutils-pr-23-gcc-O3.json:  2/3 , stage3 [00:22]
#
# [regular][1/32] Done: coreutils-pr-23-gcc-O3.json  (3 queries × 137 targets, windows=132 pairs) in 25.9s
# Run overall 0/64 [00:25<?]
# Run overall 1/64 [00:25<27:14]
# Run [regular] coreutils-pr-23-gcc-O3.json:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  0/8  [00:00]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  0/8 , stage2 [00:00]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  0/8 , stage3 [00:03]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  1/8 , stage3 [00:07]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  1/8 , stage2 [00:07]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  1/8 , stage3 [00:12]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  2/8 , stage3 [00:15]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  2/8 , stage2 [00:15]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  2/8 , stage3 [00:20]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  3/8 , stage3 [00:23]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  3/8 , stage2 [00:23]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  3/8 , stage3 [00:27]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  4/8 , stage3 [00:30]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  4/8 , stage2 [00:30]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  4/8 , stage3 [00:35]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  5/8 , stage3 [00:38]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  5/8 , stage2 [00:38]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  5/8 , stage3 [00:43]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  6/8 , stage3 [00:46]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  6/8 , stage2 [00:46]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  6/8 , stage3 [00:51]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  7/8 , stage3 [00:54]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  7/8 , stage2 [00:54]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  7/8 , stage3 [00:59]
#
# [fno_inline][1/32] Done: coreutils-pr-23-gcc-O3.json  (8 queries × 137 targets, windows=392 pairs) in 63.4s
# Run overall 1/64 [01:29<27:14]
# Run overall 2/64 [01:29<49:34]
# Run [fno_inline] coreutils-pr-23-gcc-O3.json:  0/2 , stage3 [00:00]
# Run [regular] coreutils-shred-45-gcc-O1.json:  0/2 , stage3 [00:00]
# Run [regular] coreutils-shred-45-gcc-O1.json:  0/2  [00:00]
# Run [regular] coreutils-shred-45-gcc-O1.json:  0/2 , stage2 [00:00]
# Run [regular] coreutils-shred-45-gcc-O1.json:  0/2 , stage3 [00:03]
# Run [regular] coreutils-shred-45-gcc-O1.json:  1/2 , stage3 [00:04]
# Run [regular] coreutils-shred-45-gcc-O1.json:  1/2 , stage2 [00:04]
# Run [regular] coreutils-shred-45-gcc-O1.json:  1/2 , stage3 [00:08]
#
# [regular][2/32] Done: coreutils-shred-45-gcc-O1.json  (2 queries × 114 targets, windows=70 pairs) in 9.0s
# Run overall 2/64 [01:38<49:34]
# Run overall 3/64 [01:38<30:41]
# Run [regular] coreutils-shred-45-gcc-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  0/8  [00:00]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  0/8 , stage2 [00:00]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  0/8 , stage3 [00:02]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  1/8 , stage3 [00:03]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  1/8 , stage2 [00:03]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  1/8 , stage3 [00:06]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  2/8 , stage3 [00:07]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  2/8 , stage2 [00:07]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  2/8 , stage3 [00:10]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  3/8 , stage3 [00:11]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  3/8 , stage2 [00:11]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  3/8 , stage3 [00:13]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  4/8 , stage3 [00:14]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  4/8 , stage2 [00:14]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  4/8 , stage3 [00:17]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  5/8 , stage3 [00:18]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  5/8 , stage2 [00:18]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  5/8 , stage3 [00:20]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  6/8 , stage3 [00:21]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  6/8 , stage2 [00:21]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  6/8 , stage3 [00:24]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  7/8 , stage3 [00:25]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  7/8 , stage2 [00:25]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  7/8 , stage3 [00:28]
#
# [fno_inline][2/32] Done: coreutils-shred-45-gcc-O1.json  (8 queries × 114 targets, windows=299 pairs) in 29.5s
# Run overall 3/64 [02:07<30:41]
# Run overall 4/64 [02:07<29:56]
# Run [fno_inline] coreutils-shred-45-gcc-O1.json:  0/2 , stage3 [00:00]
# Run [regular] coreutils-split-03-clang-O1.js:  0/2 , stage3 [00:00]
# Run [regular] coreutils-split-03-clang-O1.js:  0/2  [00:00]
# Run [regular] coreutils-split-03-clang-O1.js:  0/2 , stage2 [00:00]
# Run [regular] coreutils-split-03-clang-O1.js:  0/2 , stage3 [00:01]
# Run [regular] coreutils-split-03-clang-O1.js:  1/2 , stage3 [00:02]
# Run [regular] coreutils-split-03-clang-O1.js:  1/2 , stage2 [00:02]
# Run [regular] coreutils-split-03-clang-O1.js:  1/2 , stage3 [00:04]
#
# [regular][3/32] Done: coreutils-split-03-clang-O1.json  (2 queries × 90 targets, windows=22 pairs) in 7.2s
# Run overall 4/64 [02:15<29:56]
# Run overall 5/64 [02:15<21:22]
# Run [regular] coreutils-split-03-clang-O1.js:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  0/8  [00:00]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  0/8 , stage2 [00:00]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  0/8 , stage3 [00:01]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  1/8 , stage3 [00:02]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  1/8 , stage2 [00:02]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  1/8 , stage3 [00:04]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  2/8 , stage3 [00:05]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  2/8 , stage2 [00:05]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  2/8 , stage3 [00:07]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  3/8 , stage3 [00:09]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  3/8 , stage2 [00:09]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  3/8 , stage3 [00:11]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  4/8 , stage3 [00:13]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  4/8 , stage2 [00:13]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  4/8 , stage3 [00:15]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  5/8 , stage3 [00:17]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  5/8 , stage2 [00:17]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  5/8 , stage3 [00:19]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  6/8 , stage3 [00:20]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  6/8 , stage2 [00:20]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  6/8 , stage3 [00:22]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  7/8 , stage3 [00:24]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  7/8 , stage2 [00:24]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  7/8 , stage3 [00:26]
#
# [fno_inline][3/32] Done: coreutils-split-03-clang-O1.json  (8 queries × 90 targets, windows=101 pairs) in 28.1s
# Run overall 5/64 [02:43<21:22]
# Run overall 6/64 [02:43<23:05]
# Run [fno_inline] coreutils-split-03-clang-O1.js:  0/2 , stage3 [00:00]
# Run [regular] coreutils-split-03-gcc-O1.json:  0/2 , stage3 [00:00]
# Run [regular] coreutils-split-03-gcc-O1.json:  0/2  [00:00]
# Run [regular] coreutils-split-03-gcc-O1.json:  0/2 , stage2 [00:00]
# Run [regular] coreutils-split-03-gcc-O1.json:  0/2 , stage3 [00:01]
# Run [regular] coreutils-split-03-gcc-O1.json:  1/2 , stage3 [00:03]
# Run [regular] coreutils-split-03-gcc-O1.json:  1/2 , stage2 [00:03]
# Run [regular] coreutils-split-03-gcc-O1.json:  1/2 , stage3 [00:04]
#
# [regular][4/32] Done: coreutils-split-03-gcc-O1.json  (2 queries × 90 targets, windows=22 pairs) in 6.3s
# Run overall 6/64 [02:49<23:05]
# Run overall 7/64 [02:49<17:14]
# Run [regular] coreutils-split-03-gcc-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  0/8  [00:00]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  0/8 , stage2 [00:00]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  0/8 , stage3 [00:02]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  1/8 , stage3 [00:03]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  1/8 , stage2 [00:03]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  1/8 , stage3 [00:05]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  2/8 , stage3 [00:06]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  2/8 , stage2 [00:06]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  2/8 , stage3 [00:08]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  3/8 , stage3 [00:09]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  3/8 , stage2 [00:09]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  3/8 , stage3 [00:11]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  4/8 , stage3 [00:12]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  4/8 , stage2 [00:12]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  4/8 , stage3 [00:15]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  5/8 , stage3 [00:16]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  5/8 , stage2 [00:16]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  5/8 , stage3 [00:18]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  6/8 , stage3 [00:19]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  6/8 , stage2 [00:19]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  6/8 , stage3 [00:21]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  7/8 , stage3 [00:22]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  7/8 , stage2 [00:22]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  7/8 , stage3 [00:24]
#
# [fno_inline][4/32] Done: coreutils-split-03-gcc-O1.json  (8 queries × 90 targets, windows=111 pairs) in 25.4s
# Run overall 7/64 [03:14<17:14]
# Run overall 8/64 [03:14<19:05]
# Run [fno_inline] coreutils-split-03-gcc-O1.json:  0/2 , stage3 [00:00]
# Run [regular] coreutils-split-03-gcc-O3.json:  0/2 , stage3 [00:00]
# Run [regular] coreutils-split-03-gcc-O3.json:  0/2  [00:00]
# Run [regular] coreutils-split-03-gcc-O3.json:  0/2 , stage2 [00:00]
# Run [regular] coreutils-split-03-gcc-O3.json:  0/2 , stage3 [00:02]
# Run [regular] coreutils-split-03-gcc-O3.json:  1/2 , stage3 [00:04]
# Run [regular] coreutils-split-03-gcc-O3.json:  1/2 , stage2 [00:04]
# Run [regular] coreutils-split-03-gcc-O3.json:  1/2 , stage3 [00:06]
#
# [regular][5/32] Done: coreutils-split-03-gcc-O3.json  (2 queries × 106 targets, windows=58 pairs) in 8.0s
# Run overall 8/64 [03:22<19:05]
# Run overall 9/64 [03:22<15:11]
# Run [regular] coreutils-split-03-gcc-O3.json:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  0/8 , stage3 [00:00]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  0/8  [00:00]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  0/8 , stage2 [00:00]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  0/8 , stage3 [00:02]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  1/8 , stage3 [00:03]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  1/8 , stage2 [00:03]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  1/8 , stage3 [00:06]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  2/8 , stage3 [00:07]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  2/8 , stage2 [00:07]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  2/8 , stage3 [00:10]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  3/8 , stage3 [00:11]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  3/8 , stage2 [00:11]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  3/8 , stage3 [00:13]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  4/8 , stage3 [00:14]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  4/8 , stage2 [00:14]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  4/8 , stage3 [00:16]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  5/8 , stage3 [00:19]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  5/8 , stage2 [00:19]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  5/8 , stage3 [00:21]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  6/8 , stage3 [00:23]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  6/8 , stage2 [00:23]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  6/8 , stage3 [00:25]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  7/8 , stage3 [00:26]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  7/8 , stage2 [00:26]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  7/8 , stage3 [00:28]
#
# [fno_inline][5/32] Done: coreutils-split-03-gcc-O3.json  (8 queries × 106 targets, windows=255 pairs) in 30.7s
# Run overall 9/64 [03:53<15:11]
# Run overall 10/64 [03:53<18:50]
# Run [fno_inline] coreutils-split-03-gcc-O3.json:  0/24 , stage3 [00:00]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  0/24 , stage3 [00:00]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  0/24  [00:00]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  0/24 , stage1 [00:00]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  0/24 , stage2 [00:00]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  0/24 , stage3 [00:00]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  1/24 , stage3 [00:01]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  1/24 , stage1 [00:01]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  1/24 , stage2 [00:01]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  1/24 , stage3 [00:01]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  2/24 , stage3 [00:01]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  2/24 , stage1 [00:01]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  2/24 , stage2 [00:01]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  2/24 , stage3 [00:02]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  3/24 , stage3 [00:02]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  3/24 , stage1 [00:02]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  3/24 , stage2 [00:02]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  3/24 , stage3 [00:02]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  4/24 , stage3 [00:02]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  4/24 , stage1 [00:02]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  4/24 , stage2 [00:02]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  4/24 , stage3 [00:03]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  5/24 , stage3 [00:03]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  5/24 , stage1 [00:03]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  5/24 , stage2 [00:03]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  5/24 , stage3 [00:04]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  6/24 , stage3 [00:04]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  6/24 , stage1 [00:04]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  6/24 , stage2 [00:04]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  6/24 , stage3 [00:04]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  7/24 , stage3 [00:04]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  7/24 , stage1 [00:04]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  7/24 , stage2 [00:04]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  7/24 , stage3 [00:05]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  8/24 , stage3 [00:05]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  8/24 , stage1 [00:05]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  8/24 , stage2 [00:05]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  8/24 , stage3 [00:06]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  9/24 , stage3 [00:07]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  9/24 , stage1 [00:07]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  9/24 , stage2 [00:07]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  9/24 , stage3 [00:11]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  10/24 , stage3 [00:12]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  10/24 , stage1 [00:12]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  10/24 , stage2 [00:12]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  10/24 , stage3 [00:13]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  11/24 , stage3 [00:15]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  11/24 , stage1 [00:15]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  11/24 , stage2 [00:15]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  11/24 , stage3 [00:18]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  12/24 , stage3 [00:18]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  12/24 , stage1 [00:18]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  12/24 , stage2 [00:18]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  12/24 , stage3 [00:20]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  13/24 , stage3 [00:21]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  13/24 , stage1 [00:21]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  13/24 , stage2 [00:21]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  13/24 , stage3 [00:24]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  14/24 , stage3 [00:25]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  14/24 , stage1 [00:25]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  14/24 , stage2 [00:25]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  14/24 , stage3 [00:27]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  15/24 , stage3 [00:28]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  15/24 , stage1 [00:28]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  15/24 , stage2 [00:28]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  15/24 , stage3 [00:31]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  16/24 , stage3 [00:31]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  16/24 , stage1 [00:31]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  16/24 , stage2 [00:31]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  16/24 , stage3 [00:33]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  17/24 , stage3 [00:34]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  17/24 , stage1 [00:34]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  17/24 , stage2 [00:34]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  17/24 , stage3 [00:37]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  18/24 , stage3 [00:38]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  18/24 , stage1 [00:38]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  18/24 , stage2 [00:38]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  18/24 , stage3 [00:39]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  19/24 , stage3 [00:40]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  19/24 , stage1 [00:40]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  19/24 , stage2 [00:41]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  19/24 , stage3 [00:44]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  20/24 , stage3 [00:44]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  20/24 , stage1 [00:44]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  20/24 , stage2 [00:44]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  20/24 , stage3 [00:46]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  21/24 , stage3 [00:47]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  21/24 , stage1 [00:47]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  21/24 , stage2 [00:47]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  21/24 , stage3 [00:50]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  22/24 , stage3 [00:51]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  22/24 , stage1 [00:51]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  22/24 , stage2 [00:51]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  22/24 , stage3 [00:52]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  23/24 , stage3 [00:53]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  23/24 , stage1 [00:53]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  23/24 , stage2 [00:54]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  23/24 , stage3 [00:57]
#
# [regular][6/32] Done: libjpeg-cjpeg-98-clang-O1.json  (24 queries × 53 targets, windows=416 pairs) in 57.9s
# Run overall 10/64 [04:51<18:50]
# Run overall 11/64 [04:51<28:29]
# Run [regular] libjpeg-cjpeg-98-clang-O1.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  0/10  [00:00]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  0/10 , stage2 [00:00]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  0/10 , stage3 [00:02]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  1/10 , stage3 [00:07]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  1/10 , stage2 [00:07]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  1/10 , stage3 [00:09]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  2/10 , stage3 [00:16]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  2/10 , stage1 [00:16]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  2/10 , stage2 [00:18]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  2/10 , stage3 [00:21]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  3/10 , stage3 [00:28]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  3/10 , stage1 [00:28]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  3/10 , stage2 [00:30]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  3/10 , stage3 [00:35]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  4/10 , stage3 [00:41]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  4/10 , stage1 [00:41]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  4/10 , stage2 [00:43]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  4/10 , stage3 [00:48]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  5/10 , stage3 [00:55]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  5/10 , stage1 [00:55]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  5/10 , stage2 [00:56]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  5/10 , stage3 [01:01]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  6/10 , stage3 [01:09]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  6/10 , stage1 [01:09]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  6/10 , stage2 [01:10]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  6/10 , stage3 [01:13]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  7/10 , stage3 [01:21]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  7/10 , stage1 [01:21]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  7/10 , stage2 [01:22]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  7/10 , stage3 [01:27]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  8/10 , stage3 [01:33]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  8/10 , stage1 [01:33]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  8/10 , stage2 [01:35]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  8/10 , stage3 [01:40]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  9/10 , stage3 [01:46]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  9/10 , stage1 [01:46]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  9/10 , stage2 [01:48]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  9/10 , stage3 [01:52]
#
# [regular][7/32] Done: libjpeg-djpeg-06-gcc-O1.json  (10 queries × 341 targets, windows=1160 pairs) in 121.2s
# Run overall 12/64 [06:52<27:57]
# Run overall 13/64 [06:52<38:39]
# Run [regular] libjpeg-djpeg-06-gcc-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  0/8  [00:00]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  0/8 , stage2 [00:00]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  0/8 , stage3 [00:02]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  1/8 , stage3 [00:09]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  1/8 , stage2 [00:09]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  1/8 , stage3 [00:11]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  2/8 , stage3 [00:17]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  2/8 , stage2 [00:17]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  2/8 , stage3 [00:19]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  3/8 , stage3 [00:24]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  3/8 , stage2 [00:24]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  3/8 , stage3 [00:27]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  4/8 , stage3 [00:32]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  4/8 , stage2 [00:32]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  4/8 , stage3 [00:35]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  5/8 , stage3 [00:42]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  5/8 , stage2 [00:42]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  5/8 , stage3 [00:44]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  6/8 , stage3 [00:49]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  6/8 , stage2 [00:49]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  6/8 , stage3 [00:51]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  7/8 , stage3 [00:58]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  7/8 , stage2 [00:58]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  7/8 , stage3 [01:01]
#
# [fno_inline][7/32] Done: libjpeg-djpeg-06-gcc-O1.json  (8 queries × 341 targets, windows=675 pairs) in 68.3s
# Run overall 13/64 [08:01<38:39]
# Run overall 14/64 [08:01<42:38]
# Run [fno_inline] libjpeg-djpeg-06-gcc-O1.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  0/10  [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  0/10 , stage2 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  1/10 , stage3 [00:01]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  1/10 , stage2 [00:01]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  1/10 , stage3 [00:01]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  2/10 , stage3 [00:02]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  2/10 , stage1 [00:02]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  2/10 , stage2 [00:02]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  2/10 , stage3 [00:03]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  3/10 , stage3 [00:04]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  3/10 , stage1 [00:04]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  3/10 , stage2 [00:04]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  3/10 , stage3 [00:05]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  4/10 , stage3 [00:06]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  4/10 , stage1 [00:06]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  4/10 , stage2 [00:06]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  4/10 , stage3 [00:07]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  5/10 , stage3 [00:07]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  5/10 , stage1 [00:07]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  5/10 , stage2 [00:08]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  5/10 , stage3 [00:08]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  6/10 , stage3 [00:09]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  6/10 , stage1 [00:09]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  6/10 , stage2 [00:09]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  6/10 , stage3 [00:10]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  7/10 , stage3 [00:11]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  7/10 , stage1 [00:11]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  7/10 , stage2 [00:11]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  7/10 , stage3 [00:12]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  8/10 , stage3 [00:12]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  8/10 , stage1 [00:12]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  8/10 , stage2 [00:13]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  8/10 , stage3 [00:13]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  9/10 , stage3 [00:14]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  9/10 , stage1 [00:14]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  9/10 , stage2 [00:14]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  9/10 , stage3 [00:15]
#
# [regular][8/32] Done: libjpeg-djpeg-64-clang-O1.json  (10 queries × 51 targets, windows=158 pairs) in 16.9s
# Run overall 14/64 [08:17<42:38]
# Run overall 15/64 [08:17<34:25]
# Run [regular] libjpeg-djpeg-64-clang-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  0/8  [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  0/8 , stage2 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  1/8 , stage3 [00:01]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  1/8 , stage2 [00:01]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  1/8 , stage3 [00:01]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  2/8 , stage3 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  2/8 , stage2 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  2/8 , stage3 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  3/8 , stage3 [00:03]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  3/8 , stage2 [00:03]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  3/8 , stage3 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  4/8 , stage3 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  4/8 , stage2 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  4/8 , stage3 [00:05]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  5/8 , stage3 [00:06]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  5/8 , stage2 [00:06]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  5/8 , stage3 [00:06]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  6/8 , stage3 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  6/8 , stage2 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  6/8 , stage3 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  7/8 , stage3 [00:08]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  7/8 , stage2 [00:08]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  7/8 , stage3 [00:09]
#
# [fno_inline][8/32] Done: libjpeg-djpeg-64-clang-O1.json  (8 queries × 51 targets, windows=74 pairs) in 10.3s
# Run overall 15/64 [08:28<34:25]
# Run overall 16/64 [08:28<26:45]
# Run [fno_inline] libjpeg-djpeg-64-clang-O1.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  0/10  [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  0/10 , stage2 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  1/10 , stage3 [00:01]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  1/10 , stage2 [00:01]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  1/10 , stage3 [00:02]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  2/10 , stage3 [00:03]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  2/10 , stage1 [00:03]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  2/10 , stage2 [00:03]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  2/10 , stage3 [00:03]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  3/10 , stage3 [00:04]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  3/10 , stage1 [00:04]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  3/10 , stage2 [00:05]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  3/10 , stage3 [00:06]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  4/10 , stage3 [00:06]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  4/10 , stage1 [00:06]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  4/10 , stage2 [00:07]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  4/10 , stage3 [00:08]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  5/10 , stage3 [00:09]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  5/10 , stage1 [00:09]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  5/10 , stage2 [00:09]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  5/10 , stage3 [00:10]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  6/10 , stage3 [00:11]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  6/10 , stage1 [00:11]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  6/10 , stage2 [00:11]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  6/10 , stage3 [00:11]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  7/10 , stage3 [00:12]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  7/10 , stage1 [00:12]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  7/10 , stage2 [00:13]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  7/10 , stage3 [00:14]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  8/10 , stage3 [00:15]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  8/10 , stage1 [00:15]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  8/10 , stage2 [00:15]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  8/10 , stage3 [00:16]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  9/10 , stage3 [00:17]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  9/10 , stage1 [00:17]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  9/10 , stage2 [00:17]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  9/10 , stage3 [00:18]
#
# [regular][9/32] Done: libjpeg-djpeg-64-clang-O2.json  (10 queries × 51 targets, windows=176 pairs) in 19.4s
# Run overall 16/64 [08:47<26:45]
# Run overall 17/64 [08:47<23:06]
# Run [regular] libjpeg-djpeg-64-clang-O2.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  0/8  [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  0/8 , stage2 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  1/8 , stage3 [00:01]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  1/8 , stage2 [00:01]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  1/8 , stage3 [00:01]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  2/8 , stage3 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  2/8 , stage2 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  2/8 , stage3 [00:03]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  3/8 , stage3 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  3/8 , stage2 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  3/8 , stage3 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  4/8 , stage3 [00:05]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  4/8 , stage2 [00:05]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  4/8 , stage3 [00:06]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  5/8 , stage3 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  5/8 , stage2 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  5/8 , stage3 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  6/8 , stage3 [00:08]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  6/8 , stage2 [00:08]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  6/8 , stage3 [00:09]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  7/8 , stage3 [00:10]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  7/8 , stage2 [00:10]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  7/8 , stage3 [00:10]
#
# [fno_inline][9/32] Done: libjpeg-djpeg-64-clang-O2.json  (8 queries × 51 targets, windows=90 pairs) in 11.6s
# Run overall 17/64 [08:59<23:06]
# Run overall 18/64 [08:59<18:41]
# Run [fno_inline] libjpeg-djpeg-64-clang-O2.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  0/10  [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  0/10 , stage2 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  1/10 , stage3 [00:02]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  1/10 , stage2 [00:02]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  1/10 , stage3 [00:03]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  2/10 , stage3 [00:04]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  2/10 , stage1 [00:04]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  2/10 , stage2 [00:04]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  2/10 , stage3 [00:05]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  3/10 , stage3 [00:07]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  3/10 , stage1 [00:07]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  3/10 , stage2 [00:07]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  3/10 , stage3 [00:09]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  4/10 , stage3 [00:10]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  4/10 , stage1 [00:10]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  4/10 , stage2 [00:10]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  4/10 , stage3 [00:12]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  5/10 , stage3 [00:13]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  5/10 , stage1 [00:13]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  5/10 , stage2 [00:13]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  5/10 , stage3 [00:14]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  6/10 , stage3 [00:15]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  6/10 , stage1 [00:15]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  6/10 , stage2 [00:16]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  6/10 , stage3 [00:17]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  7/10 , stage3 [00:18]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  7/10 , stage1 [00:18]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  7/10 , stage2 [00:18]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  7/10 , stage3 [00:20]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  8/10 , stage3 [00:21]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  8/10 , stage1 [00:21]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  8/10 , stage2 [00:22]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  8/10 , stage3 [00:23]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  9/10 , stage3 [00:24]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  9/10 , stage1 [00:24]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  9/10 , stage2 [00:24]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  9/10 , stage3 [00:26]
#
# [regular][10/32] Done: libjpeg-djpeg-64-clang-O3.json  (10 queries × 51 targets, windows=184 pairs) in 27.5s
# Run overall 18/64 [09:26<18:41]
# Run overall 19/64 [09:26<18:58]
# Run [regular] libjpeg-djpeg-64-clang-O3.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  0/8  [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  0/8 , stage2 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  1/8 , stage3 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  1/8 , stage2 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  1/8 , stage3 [00:03]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  2/8 , stage3 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  2/8 , stage2 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  2/8 , stage3 [00:05]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  3/8 , stage3 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  3/8 , stage2 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  3/8 , stage3 [00:08]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  4/8 , stage3 [00:09]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  4/8 , stage2 [00:09]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  4/8 , stage3 [00:10]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  5/8 , stage3 [00:11]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  5/8 , stage2 [00:11]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  5/8 , stage3 [00:12]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  6/8 , stage3 [00:14]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  6/8 , stage2 [00:14]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  6/8 , stage3 [00:15]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  7/8 , stage3 [00:16]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  7/8 , stage2 [00:16]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  7/8 , stage3 [00:17]
#
# [fno_inline][10/32] Done: libjpeg-djpeg-64-clang-O3.json  (8 queries × 51 targets, windows=105 pairs) in 19.4s
# Run overall 19/64 [09:46<18:58]
# Run overall 20/64 [09:46<17:16]
# Run [fno_inline] libjpeg-djpeg-64-clang-O3.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  0/10  [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  0/10 , stage2 [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  1/10 , stage3 [00:01]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  1/10 , stage2 [00:01]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  1/10 , stage3 [00:01]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  2/10 , stage3 [00:02]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  2/10 , stage1 [00:02]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  2/10 , stage2 [00:02]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  2/10 , stage3 [00:03]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  3/10 , stage3 [00:04]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  3/10 , stage1 [00:04]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  3/10 , stage2 [00:04]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  3/10 , stage3 [00:05]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  4/10 , stage3 [00:05]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  4/10 , stage1 [00:05]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  4/10 , stage2 [00:06]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  4/10 , stage3 [00:06]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  5/10 , stage3 [00:07]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  5/10 , stage1 [00:07]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  5/10 , stage2 [00:07]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  5/10 , stage3 [00:08]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  6/10 , stage3 [00:09]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  6/10 , stage1 [00:09]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  6/10 , stage2 [00:09]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  6/10 , stage3 [00:10]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  7/10 , stage3 [00:11]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  7/10 , stage1 [00:11]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  7/10 , stage2 [00:11]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  7/10 , stage3 [00:12]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  8/10 , stage3 [00:13]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  8/10 , stage1 [00:13]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  8/10 , stage2 [00:13]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  8/10 , stage3 [00:14]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  9/10 , stage3 [00:14]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  9/10 , stage1 [00:14]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  9/10 , stage2 [00:14]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  9/10 , stage3 [00:15]
#
# [regular][11/32] Done: libjpeg-djpeg-64-gcc-O1.json  (10 queries × 51 targets, windows=158 pairs) in 16.6s
# Run overall 20/64 [10:02<17:16]
# Run overall 21/64 [10:02<15:24]
# Run [regular] libjpeg-djpeg-64-gcc-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  0/8  [00:00]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  0/8 , stage2 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  0/8 , stage3 [00:00]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  1/8 , stage3 [00:01]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  1/8 , stage2 [00:01]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  1/8 , stage3 [00:01]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  2/8 , stage3 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  2/8 , stage2 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  2/8 , stage3 [00:02]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  3/8 , stage3 [00:03]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  3/8 , stage2 [00:03]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  3/8 , stage3 [00:03]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  4/8 , stage3 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  4/8 , stage2 [00:04]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  4/8 , stage3 [00:05]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  5/8 , stage3 [00:05]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  5/8 , stage2 [00:05]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  5/8 , stage3 [00:06]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  6/8 , stage3 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  6/8 , stage2 [00:07]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  6/8 , stage3 [00:08]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  7/8 , stage3 [00:08]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  7/8 , stage2 [00:09]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  7/8 , stage3 [00:09]
#
# [fno_inline][11/32] Done: libjpeg-djpeg-64-gcc-O1.json  (8 queries × 51 targets, windows=74 pairs) in 10.3s
# Run overall 21/64 [10:13<15:24]
# Run overall 22/64 [10:13<12:43]
# Run [fno_inline] libjpeg-djpeg-64-gcc-O1.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O2.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O2.json:  0/10  [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O2.json:  0/10 , stage2 [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O2.json:  0/10 , stage3 [00:00]
# Run [regular] libjpeg-djpeg-64-gcc-O2.json:  1/10 , stage3 [00:01]
# ...
# [+] Vuln DBs to process: ['regular', 'fno_inline']
# [+] Running all stages: Stage 1, 2, 3 (early-exit at >= 0.99)
# [+] Filter (pre-filter, minimum code-mass): ENABLED  alpha = 0.54
# [+] Target files to process: 32
# WARNING:tensorflow:From /usr/local/lib/python3.13/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789614687.856768   22871 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# [+] SAFE model loaded, running on GPU
#
# ========== Vuln DB: regular ==========
# [+] Loaded 139 vulnerable functions
# I0000 00:00:1789614688.601174   22871 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# [regular][1/32] Done: coreutils-pr-23-gcc-O3.json  (3 queries x 141 targets) in 39.9s
# [regular][2/32] Done: coreutils-shred-45-gcc-O1.json  (2 queries x 117 targets) in 9.0s
# [regular][3/32] Done: coreutils-split-03-clang-O1.json  (2 queries x 93 targets) in 6.3s
# [regular][4/32] Done: coreutils-split-03-gcc-O1.json  (2 queries x 93 targets) in 5.2s
# [regular][5/32] Done: coreutils-split-03-gcc-O3.json  (2 queries x 70 targets) in 8.5s
# [regular][6/32] Done: libjpeg-cjpeg-98-clang-O1.json  (24 queries x 56 targets) in 67.7s
# [regular][7/32] Done: libjpeg-djpeg-06-gcc-O1.json  (10 queries x 291 targets) in 178.3s
# [regular][8/32] Done: libjpeg-djpeg-64-clang-O1.json  (10 queries x 54 targets) in 34.3s
# [regular][9/32] Done: libjpeg-djpeg-64-clang-O2.json  (10 queries x 54 targets) in 39.2s
# [regular][10/32] Done: libjpeg-djpeg-64-clang-O3.json  (10 queries x 54 targets) in 45.6s
# [regular][11/32] Done: libjpeg-djpeg-64-gcc-O1.json  (10 queries x 54 targets) in 36.0s
# [regular][12/32] Done: libjpeg-djpeg-64-gcc-O2.json  (10 queries x 54 targets) in 40.1s
# [regular][13/32] Done: libjpeg-djpeg-64-gcc-O3.json  (10 queries x 54 targets) in 45.7s
# [regular][14/32] Done: libming-listmp3-64-clang-O2.json  (16 queries x 10 targets) in 6.4s
# [regular][15/32] Done: libming-listmp3-64-clang-O3.json  (16 queries x 10 targets) in 7.5s
# [regular][16/32] Done: libming-listmp3-64-gcc-O1.json  (16 queries x 10 targets) in 5.9s
# [regular][17/32] Done: libming-listmp3-64-gcc-O3.json  (16 queries x 10 targets) in 7.3s
# [regular][18/32] Done: libming-listmp3-65-clang-O2.json  (16 queries x 10 targets) in 7.7s
# [regular][19/32] Done: libming-listmp3-65-clang-O3.json  (16 queries x 10 targets) in 6.8s
# [regular][20/32] Done: libming-listmp3-65-gcc-O1.json  (16 queries x 10 targets) in 7.4s
# [regular][21/32] Done: libming-listmp3-65-gcc-O2.json  (16 queries x 10 targets) in 6.6s
# [regular][22/32] Done: libming-listmp3-65-gcc-O3.json  (16 queries x 10 targets) in 8.3s
# [regular][23/32] Done: libming-listswf-27-clang-O2.json  (32 queries x 427 targets) in 912.4s
# [regular][24/32] Done: libming-listswf-27-gcc-O3.json  (32 queries x 388 targets) in 715.9s
# [regular][25/32] Done: libtiff-tiffcrop-71-gcc-O1.json  (8 queries x 560 targets) in 230.5s
# [regular][26/32] Done: libtiff-tiffcrop-92-gcc-O2.json  (8 queries x 541 targets) in 230.1s
# [regular][27/32] Done: libtiff-tiffinfo-25-clang-O1.json  (8 queries x 411 targets) in 219.0s
# [regular][28/32] Done: libtiff-tiffinfo-25-gcc-O1.json  (8 queries x 430 targets) in 201.9s
# [regular][29/32] Done: libtiff-tiffinfo-25-gcc-O3.json  (8 queries x 400 targets) in 268.3s
# [regular][30/32] Done: libtiff-tiffsplit-95-gcc-O2.json  (16 queries x 463 targets) in 247.7s
# [regular][31/32] Done: zziplib-unzzipcatmem-74-clang-O2.json  (18 queries x 50 targets) in 27.3s
# [regular][32/32] Done: zziplib-unzzipcatmem-74-gcc-O2.json  (18 queries x 51 targets) in 24.8s
#
# ========== Vuln DB: fno_inline ==========
# [+] Loaded 81 vulnerable functions
# [fno_inline][1/32] Done: coreutils-pr-23-gcc-O3.json  (8 queries x 141 targets) in 74.9s
# [fno_inline][2/32] Done: coreutils-shred-45-gcc-O1.json  (8 queries x 117 targets) in 37.0s
# [fno_inline][3/32] Done: coreutils-split-03-clang-O1.json  (8 queries x 93 targets) in 22.7s
# [fno_inline][4/32] Done: coreutils-split-03-gcc-O1.json  (8 queries x 93 targets) in 24.4s
# [fno_inline][5/32] Done: coreutils-split-03-gcc-O3.json  (8 queries x 70 targets) in 34.8s
# [fno_inline][7/32] Done: libjpeg-djpeg-06-gcc-O1.json  (8 queries x 291 targets) in 102.7s
# [fno_inline][8/32] Done: libjpeg-djpeg-64-clang-O1.json  (8 queries x 54 targets) in 19.1s
# [fno_inline][9/32] Done: libjpeg-djpeg-64-clang-O2.json  (8 queries x 54 targets) in 21.2s
# [fno_inline][10/32] Done: libjpeg-djpeg-64-clang-O3.json  (8 queries x 54 targets) in 26.5s
# [fno_inline][11/32] Done: libjpeg-djpeg-64-gcc-O1.json  (8 queries x 54 targets) in 19.1s
# [fno_inline][12/32] Done: libjpeg-djpeg-64-gcc-O2.json  (8 queries x 54 targets) in 22.5s
# [fno_inline][13/32] Done: libjpeg-djpeg-64-gcc-O3.json  (8 queries x 54 targets) in 26.5s
# [fno_inline][14/32] Done: libming-listmp3-64-clang-O2.json  (8 queries x 10 targets) in 3.2s
# [fno_inline][15/32] Done: libming-listmp3-64-clang-O3.json  (8 queries x 10 targets) in 3.1s
# [fno_inline][16/32] Done: libming-listmp3-64-gcc-O1.json  (8 queries x 10 targets) in 4.4s
# [fno_inline][17/32] Done: libming-listmp3-64-gcc-O3.json  (8 queries x 10 targets) in 3.1s
# [fno_inline][18/32] Done: libming-listmp3-65-clang-O2.json  (8 queries x 10 targets) in 3.2s
# [fno_inline][19/32] Done: libming-listmp3-65-clang-O3.json  (8 queries x 10 targets) in 3.2s
# [fno_inline][20/32] Done: libming-listmp3-65-gcc-O1.json  (8 queries x 10 targets) in 4.5s
# [fno_inline][21/32] Done: libming-listmp3-65-gcc-O2.json  (8 queries x 10 targets) in 3.3s
# [fno_inline][22/32] Done: libming-listmp3-65-gcc-O3.json  (8 queries x 10 targets) in 3.2s
# [fno_inline][23/32] Done: libming-listswf-27-clang-O2.json  (9 queries x 427 targets) in 229.1s
# [fno_inline][24/32] Done: libming-listswf-27-gcc-O3.json  (9 queries x 388 targets) in 169.9s
# [fno_inline][25/32] Done: libtiff-tiffcrop-71-gcc-O1.json  (16 queries x 560 targets) in 520.0s
# [fno_inline][26/32] Done: libtiff-tiffcrop-92-gcc-O2.json  (16 queries x 541 targets) in 502.3s
# [fno_inline][30/32] Done: libtiff-tiffsplit-95-gcc-O2.json  (8 queries x 463 targets) in 30.7s
# [fno_inline][31/32] Done: zziplib-unzzipcatmem-74-clang-O2.json  (8 queries x 50 targets) in 7.1s
# [fno_inline][32/32] Done: zziplib-unzzipcatmem-74-gcc-O2.json  (8 queries x 51 targets) in 6.7s
#
# [+] All done!
# [+] Grand totals: processed=60, exists=0, no_vuln=4
# [+] Total wall time: 5663.2s (01:34:23)
#
# [+] Per-stage totals (this process, all files/DBs processed):
#     stage1: calls=23757    total=   170.19s avg/call=0.0072s
#     stage2: calls=904643   total=  2321.10s avg/call=0.0026s
#     stage3: calls=4624597  total=  3024.91s avg/call=0.0007s
#
# == SAFE: the same subset with Stage 1 only
# [+] SAFE backbone, MAX_INSTRUCTION: 150
# [+] Vuln DBs to process: ['regular', 'fno_inline']
# [+] Running Stage 1 only
# [+] Filter (pre-filter, minimum code-mass): ENABLED  alpha = 0.54
# [+] Target files to process: 32
# WARNING:tensorflow:From /usr/local/lib/python3.13/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789620359.211585   46034 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# [+] SAFE model loaded, running on GPU
#
# ========== Vuln DB: regular ==========
# [+] Loaded 139 vulnerable functions
# I0000 00:00:1789620360.153170   46034 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# [regular][1/32] Done: coreutils-pr-23-gcc-O3.json  (3 queries x 141 targets) in 19.2s
# [regular][2/32] Done: coreutils-shred-45-gcc-O1.json  (2 queries x 117 targets) in 3.3s
# [regular][3/32] Done: coreutils-split-03-clang-O1.json  (2 queries x 93 targets) in 1.6s
# [regular][4/32] Done: coreutils-split-03-gcc-O1.json  (2 queries x 93 targets) in 2.5s
# [regular][5/32] Done: coreutils-split-03-gcc-O3.json  (2 queries x 70 targets) in 3.0s
# [regular][6/32] Done: libjpeg-cjpeg-98-clang-O1.json  (24 queries x 56 targets) in 5.7s
# [regular][7/32] Done: libjpeg-djpeg-06-gcc-O1.json  (10 queries x 291 targets) in 13.2s
# [regular][8/32] Done: libjpeg-djpeg-64-clang-O1.json  (10 queries x 54 targets) in 4.8s
# [regular][9/32] Done: libjpeg-djpeg-64-clang-O2.json  (10 queries x 54 targets) in 3.9s
# [regular][10/32] Done: libjpeg-djpeg-64-clang-O3.json  (10 queries x 54 targets) in 3.9s
# [regular][11/32] Done: libjpeg-djpeg-64-gcc-O1.json  (10 queries x 54 targets) in 4.8s
# [regular][12/32] Done: libjpeg-djpeg-64-gcc-O2.json  (10 queries x 54 targets) in 4.0s
# [regular][13/32] Done: libjpeg-djpeg-64-gcc-O3.json  (10 queries x 54 targets) in 4.1s
# [regular][14/32] Done: libming-listmp3-64-clang-O2.json  (16 queries x 10 targets) in 3.2s
# [regular][15/32] Done: libming-listmp3-64-clang-O3.json  (16 queries x 10 targets) in 2.7s
# [regular][16/32] Done: libming-listmp3-64-gcc-O1.json  (16 queries x 10 targets) in 2.4s
# [regular][17/32] Done: libming-listmp3-64-gcc-O3.json  (16 queries x 10 targets) in 2.3s
# [regular][18/32] Done: libming-listmp3-65-clang-O2.json  (16 queries x 10 targets) in 2.4s
# [regular][19/32] Done: libming-listmp3-65-clang-O3.json  (16 queries x 10 targets) in 3.3s
# [regular][20/32] Done: libming-listmp3-65-gcc-O1.json  (16 queries x 10 targets) in 2.5s
# [regular][21/32] Done: libming-listmp3-65-gcc-O2.json  (16 queries x 10 targets) in 2.3s
# [regular][22/32] Done: libming-listmp3-65-gcc-O3.json  (16 queries x 10 targets) in 2.4s
# [regular][23/32] Done: libming-listswf-27-clang-O2.json  (32 queries x 427 targets) in 27.6s
# [regular][24/32] Done: libming-listswf-27-gcc-O3.json  (32 queries x 388 targets) in 23.0s
# [regular][25/32] Done: libtiff-tiffcrop-71-gcc-O1.json  (8 queries x 560 targets) in 26.9s
# [regular][26/32] Done: libtiff-tiffcrop-92-gcc-O2.json  (8 queries x 541 targets) in 29.1s
# [regular][27/32] Done: libtiff-tiffinfo-25-clang-O1.json  (8 queries x 411 targets) in 18.0s
# [regular][28/32] Done: libtiff-tiffinfo-25-gcc-O1.json  (8 queries x 430 targets) in 16.6s
# [regular][29/32] Done: libtiff-tiffinfo-25-gcc-O3.json  (8 queries x 400 targets) in 21.5s
# [regular][30/32] Done: libtiff-tiffsplit-95-gcc-O2.json  (16 queries x 463 targets) in 24.2s
# [regular][31/32] Done: zziplib-unzzipcatmem-74-clang-O2.json  (18 queries x 50 targets) in 2.1s
# [regular][32/32] Done: zziplib-unzzipcatmem-74-gcc-O2.json  (18 queries x 51 targets) in 1.9s
#
# ========== Vuln DB: fno_inline ==========
# [+] Loaded 81 vulnerable functions
# [fno_inline][1/32] Done: coreutils-pr-23-gcc-O3.json  (8 queries x 141 targets) in 7.9s
# [fno_inline][2/32] Done: coreutils-shred-45-gcc-O1.json  (8 queries x 117 targets) in 3.8s
# [fno_inline][3/32] Done: coreutils-split-03-clang-O1.json  (8 queries x 93 targets) in 2.7s
# [fno_inline][4/32] Done: coreutils-split-03-gcc-O1.json  (8 queries x 93 targets) in 3.8s
# [fno_inline][5/32] Done: coreutils-split-03-gcc-O3.json  (8 queries x 70 targets) in 3.5s
# [fno_inline][7/32] Done: libjpeg-djpeg-06-gcc-O1.json  (8 queries x 291 targets) in 9.1s
# [fno_inline][8/32] Done: libjpeg-djpeg-64-clang-O1.json  (8 queries x 54 targets) in 2.4s
# [fno_inline][9/32] Done: libjpeg-djpeg-64-clang-O2.json  (8 queries x 54 targets) in 2.7s
# [fno_inline][10/32] Done: libjpeg-djpeg-64-clang-O3.json  (8 queries x 54 targets) in 3.0s
# [fno_inline][11/32] Done: libjpeg-djpeg-64-gcc-O1.json  (8 queries x 54 targets) in 3.6s
# [fno_inline][12/32] Done: libjpeg-djpeg-64-gcc-O2.json  (8 queries x 54 targets) in 2.7s
# [fno_inline][13/32] Done: libjpeg-djpeg-64-gcc-O3.json  (8 queries x 54 targets) in 2.9s
# [fno_inline][14/32] Done: libming-listmp3-64-clang-O2.json  (8 queries x 10 targets) in 1.2s
# [fno_inline][15/32] Done: libming-listmp3-64-clang-O3.json  (8 queries x 10 targets) in 1.2s
# [fno_inline][16/32] Done: libming-listmp3-64-gcc-O1.json  (8 queries x 10 targets) in 1.3s
# [fno_inline][17/32] Done: libming-listmp3-64-gcc-O3.json  (8 queries x 10 targets) in 1.7s
# [fno_inline][18/32] Done: libming-listmp3-65-clang-O2.json  (8 queries x 10 targets) in 2.0s
# [fno_inline][19/32] Done: libming-listmp3-65-clang-O3.json  (8 queries x 10 targets) in 1.2s
# [fno_inline][20/32] Done: libming-listmp3-65-gcc-O1.json  (8 queries x 10 targets) in 1.2s
# [fno_inline][21/32] Done: libming-listmp3-65-gcc-O2.json  (8 queries x 10 targets) in 1.2s
# [fno_inline][22/32] Done: libming-listmp3-65-gcc-O3.json  (8 queries x 10 targets) in 1.2s
# [fno_inline][23/32] Done: libming-listswf-27-clang-O2.json  (9 queries x 427 targets) in 23.2s
# [fno_inline][24/32] Done: libming-listswf-27-gcc-O3.json  (9 queries x 388 targets) in 17.2s
# [fno_inline][25/32] Done: libtiff-tiffcrop-71-gcc-O1.json  (16 queries x 560 targets) in 27.7s
# [fno_inline][26/32] Done: libtiff-tiffcrop-92-gcc-O2.json  (16 queries x 541 targets) in 29.4s
# [fno_inline][30/32] Done: libtiff-tiffsplit-95-gcc-O2.json  (8 queries x 463 targets) in 2.6s
# [fno_inline][31/32] Done: zziplib-unzzipcatmem-74-clang-O2.json  (8 queries x 50 targets) in 1.6s
# [fno_inline][32/32] Done: zziplib-unzzipcatmem-74-gcc-O2.json  (8 queries x 51 targets) in 1.5s
#
# [+] All done!
# [+] Grand totals: processed=60, exists=0, no_vuln=4
# [+] Total wall time: 452.8s (00:07:32)
#
# [+] Per-stage totals (this process, all files/DBs processed):
#     stage1: calls=40251    total=   361.51s avg/call=0.0090s
#     stage2: calls=0        total=     0.00s avg/call=0.0000s
#     stage3: calls=0        total=     0.00s avg/call=0.0000s
#
# == computing type-wise Top-K tables
#
# Wrote 53 tables → /content/pinpoint/claims/claim1/actual/topk.binshot.cascade.txt
#
# Wrote 53 tables → /content/pinpoint/claims/claim1/actual/topk.binshot.stage1.txt
#
# Wrote 53 tables → /content/pinpoint/claims/claim1/actual/topk.safe.cascade.txt
#
# Wrote 53 tables → /content/pinpoint/claims/claim1/actual/topk.safe.stage1.txt
#
# TABLE III: Type-wise and overall Top-K function-retrieval accuracy and MRR of
# PinPoint and the baseline BCSD models. For each target-function instance, rank
# is the best rank over all references derived from the same vulnerable function.
# T1, T5 and T10 denote Top-1, Top-5 and Top-10 accuracy. Each backbone is
# evaluated standalone, with whole-function matching only, and as a PinPoint
# backbone, which adds the block-stride and token-stride stages. Overall
# aggregates Types I-IV.
#
#                            Type I                   Type II                 Type III                  Type IV                  Overall
# Model                 T1    T5   T10    MRR    T1    T5   T10    MRR    T1    T5   T10    MRR    T1    T5   T10    MRR    T1    T5   T10    MRR
# -----------------------------------------------------------------------------------------------------------------------------------------------
# BinShot             89.5  92.4  93.9  0.914  40.8  64.9  73.4  0.508  98.5  98.5  98.5  0.986  75.0  87.5  87.5  0.818  69.5  80.1  84.0  0.742
# PinPoint-BinShot    87.0  89.9  90.6  0.884  55.7  68.1  78.7  0.618  99.3  99.3  99.3  0.993  87.5  87.5  87.5  0.877  74.6  80.5  84.9  0.775
# SAFE                87.4  96.0  96.4  0.911   8.4  16.4  24.5  0.144  97.8  99.3  99.3  0.984  50.0  62.5  75.0  0.568  52.3  58.8  62.2  0.561
# PinPoint-SAFE       77.9  91.3  92.9  0.828  15.0  28.1  41.2  0.221  98.5  99.3  99.3  0.989  50.0  75.0 100.0  0.617  51.7  61.7  67.5  0.563
# -----------------------------------------------------------------------------------------------------------------------------------------------

# %%
# !bash /content/pinpoint/claims/claim2/run.sh
# Out:
# == running PinPoint's full cascade over the subset
# [+] Using device: cuda:0
# [+] MAX_TOKENS: 253
# [+] Vuln DBs to process: ['regular', 'fno_inline']
# [+] Running all stages: Stage 1, 2, 3 (early-exit at >= 0.99)
# [+] Filter (pre-filter, minimum code-mass): ENABLED  α = 0.54
# [+] Loading vocabulary from /content/pinpoint/artifact/models/pretrain.all.corpus.voca
# [+] Loaded 17992 vocas
# [+] Loading similarity model from /content/pinpoint/artifact/models/binshot_sim.model
# [+] Excluded 0 files with opts ['O0'] (32 remain)
# [+] Target files to process: 32
# [+] Mode: SAME project/binary only
#
# ========== Vuln DB: regular ==========
# [+] Path: /content/pinpoint/artifact/data/reference_db/default.json
# [+] Output dir: /content/pinpoint/artifact/results/cascade/regular
# [+] Loading vulnerable functions from /content/pinpoint/artifact/data/reference_db/default.json
# [+] Loaded 139 vulnerable functions
# [+] Loaded 139 vuln queries from DB
# [+] Loading pre-computed embeddings for 'regular' from /content/pinpoint/artifact/data/reference_embeddings/reference_embeddings_regular.pt
# [+] Loaded 139 embeddings (mode: unified)
#
# ========== Vuln DB: fno_inline ==========
# [+] Path: /content/pinpoint/artifact/data/reference_db/fno_inline.json
# [+] Output dir: /content/pinpoint/artifact/results/cascade/fno_inline
# [+] Loading vulnerable functions from /content/pinpoint/artifact/data/reference_db/fno_inline.json
# [+] Loaded 81 vulnerable functions
# [+] Loaded 81 vuln queries from DB
# [+] Loading pre-computed embeddings for 'fno_inline' from /content/pinpoint/artifact/data/reference_embeddings/reference_embeddings_fno_inline.pt
# [+] Loaded 81 embeddings (mode: unified)
# Run overall 0/64 [00:00<?]
# Run overall (done):  64/64 [00:00<00:00]
#
# Run (done):  0/1  [00:00]
# [regular] done: processed=0, exists=32, locked=0, no_vuln=0
# [fno_inline] done: processed=0, exists=28, locked=0, no_vuln=4
#
# [+] All done!
# [+] Grand totals: processed=0, exists=60, locked=0, no_vuln=4
# [+] Total wall time: 0.5s (00:00:00)
#
# == scoring the reported ranges against the DWARF ground truth
# TABLE IV: Within-function vulnerability range localization of
# PinPoint-BinShot for reference queries whose ground-truth target appears at
# Top-1. #Queries denotes the number of such reference queries. A query is
# counted as Correct when at least one reported range overlaps the vulnerable
# region; complete coverage of the region is not required. Accuracy is the
# fraction of correct queries within each type.
#
#   Type        #Queries    #Correct    Accuracy
#   --------------------------------------------
#   I                126         126      100.0%
#   II               151         119       78.8%
#   III               24          24      100.0%
#   IV                10          10      100.0%
#   --------------------------------------------
#   Total            311         279       89.7%
#
#   json    : claims/claim2/actual/claim2.json
